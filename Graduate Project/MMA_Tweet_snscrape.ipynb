# %%
import snscrape
import snscrape.modules.twitter as sntwitter
import pandas as pd
# show all
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# User search
# Creating list to append tweet data to
text_list_Conor = []

# collect the tweets from Conor McGregor and khabib nurmagomedov because their are the main even fighters.
# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:TheNotoriousMMA since:2018-08-23, until:2018-10-07, lang:en').get_items()):
    if i > 100:
        break
    text_list_Conor.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.content])
    
# Creating a dataframe to load the list
tweets_Conor = pd.DataFrame(text_list_Conor, columns=["User", "Date Created", "Number of Likes", "Tweet"])

# %%
pd.set_option('display.max_colwidth', None)
tweets_Conor.index
tweets_Conor.sample(5)
# Out:
# RangeIndex(start=0, stop=33, step=1)
#                User              Date Created  Number of Likes  \
# 0   TheNotoriousMMA 2018-10-06 07:44:43+00:00            36778
# 14  TheNotoriousMMA 2018-09-23 20:30:13+00:00            10244
# 31  TheNotoriousMMA 2018-08-25 15:28:34+00:00             7024
# 15  TheNotoriousMMA 2018-09-22 00:13:44+00:00             7409
# 32  TheNotoriousMMA 2018-08-24 15:09:41+00:00             3816
#
#                                                                                                                                                                                                                        Tweet
# 0                                                                                                                                     The Notorious Tiger @beatsbydre! \nThank you Jimmy and Dre 🐅 🎧 https://t.co/f5El6alw4U
# ...

# %%
# User search
# Creating list to append tweet data to
text_list_Khabib = []

# collect the tweets from Conor McGregor and khabib nurmagomedov because their are the main even fighters.
# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:TeamKhabib since:2018-08-23, until:2018-10-07, lang:en').get_items()):
    if i > 100:
        break
    text_list_Khabib.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.content])
    
# Creating a dataframe to load the list
tweets_Khabib = pd.DataFrame(text_list_Khabib, columns=["User", "Date Created", "Number of Likes", "Tweet"])

# %%
tweets_Khabib.index
tweets_Khabib.sample(5)
# Out:
# RangeIndex(start=0, stop=33, step=1)
#           User              Date Created  Number of Likes  \
# 21  TeamKhabib 2018-09-16 13:36:38+00:00             1117
# 28  TeamKhabib 2018-08-26 05:21:45+00:00             5259
# 9   TeamKhabib 2018-09-27 05:45:15+00:00             2811
# 12  TeamKhabib 2018-09-26 06:40:28+00:00             1387
# 18  TeamKhabib 2018-09-19 00:15:39+00:00              337
#
#                                                 Tweet
# 21                   20 days. https://t.co/TrHwCchkSv
# 28  @Justin_Gaethje is a monster, always fun to wa...
# 9   Just want to thank my brother @Cody_Nolove for...
# 12  Wrestling practice with double champ @dc_mma t...
# 18  With Kansas city bandit 💰\n\nThe one and only ...

# %%
# User search
# Creating list to append tweet data to
text_list_Conor = []

# collect the tweets from Conor McGregor and khabib nurmagomedov because their are the main even fighters.
# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:TheNotoriousMMA OR from:TeamKhabib since:2018-08-23, until:2018-10-07, , lang:en').get_items()):
    if i > 100:
        break
    text_list_Conor.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_Conor_Khabib = pd.DataFrame(text_list_Conor, columns=["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"])

# %%
print(tweets_Conor_Khabib.head(15))
print(tweets_Conor_Khabib.index)
# Out:
#                User              Date Created  Number of Likes  \
# 0   TheNotoriousMMA 2018-10-06 07:44:43+00:00            36862
# 1   TheNotoriousMMA 2018-10-06 02:15:36+00:00            10588
# 2   TheNotoriousMMA 2018-10-06 01:54:47+00:00           161711
# 3        TeamKhabib 2018-10-05 08:20:13+00:00             3623
# 4        TeamKhabib 2018-10-04 21:29:07+00:00             3071
# 5        TeamKhabib 2018-10-04 06:32:10+00:00             1291
# 6   TheNotoriousMMA 2018-10-04 05:26:10+00:00            12234
# 7        TeamKhabib 2018-10-03 06:55:53+00:00             1321
# 8   TheNotoriousMMA 2018-10-03 05:34:24+00:00            11920
# 9   TheNotoriousMMA 2018-10-02 11:04:48+00:00            69572
# 10       TeamKhabib 2018-10-02 06:32:17+00:00             1504
# 11  TheNotoriousMMA 2018-10-01 23:25:10+00:00            11066
# 12       TeamKhabib 2018-10-01 20:56:59+00:00             1002
# 13  TheNotoriousMMA 2018-09-29 23:38:57+00:00            10610
# ...

# %%
tweets_Conor_Khabib.to_csv('tweets_Conor_Khabib.csv', index = False)

# %%
# the keywords will be ufc229, ufc, TheNotoriousMMA, TeamKhabib
text_keywords = []

for i, tweet in enumerate(sntwitter.TwitterSearchScraper('ufc229 OR ufc OR TheNotoriousMMA OR TeamKhabib since:2018-08-23, until:2018-10-07, lang:en').get_items()):
    text_keywords.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
    
text_ufc229_df = pd.DataFrame(text_keywords, columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-139e2dd3e4bb> in <module>
#       2 text_keywords = []
#       3
# ----> 4 for i, tweet in enumerate(sntwitter.TwitterSearchScraper('ufc229 OR ufc OR TheNotoriousMMA OR TeamKhabib since:2018-08-23, until:2018-10-07, lang:en').get_items()):
#       5     text_keywords.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
#       6
#
# /usr/local/lib/python3.9/site-packages/snscrape/modules/twitter.py in get_items(self)
#     678                         del paginationParams['tweet_search_mode']
#     679
# --> 680                 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', params, paginationParams, cursor = self._cursor):
#     681                         yield from self._instructions_to_tweets(obj)
#     682
#
# ...

# %%
text_ufc229_df.sample(10)
text_ufc229_df.index

# %%
text_ufc229_df.to_csv('text_keywords.csv', index = False)

# %%
dataset = pd.read_csv('text_keywords.csv', encoding='utf-8')
dataset
# Out:
#                    User               Date Created  Number of Likes  \
# 0           mmafightbiz  2018-10-06 23:59:58+00:00              0.0
# 1        Jamison5Thomas  2018-10-06 23:59:58+00:00              2.0
# 2             OddsShark  2018-10-06 23:59:56+00:00              5.0
# 3        MatolyakAttack  2018-10-06 23:59:55+00:00              1.0
# 4       JoshuaApot18397  2018-10-06 23:59:55+00:00             17.0
# ...                 ...                        ...              ...
# 339126    ShoMEyourNUTS  2018-08-23 00:01:28+00:00              0.0
# 339127    mmasocialclub  2018-08-23 00:01:10+00:00              0.0
# 339128       angrymarks  2018-08-23 00:01:02+00:00              0.0
# 339129   DJANONYMOUSDRG  2018-08-23 00:00:54+00:00              0.0
# 339130         mmamania  2018-08-23 00:00:05+00:00              2.0
#
#                    Source of Tweet  \
# 0                    WordPress.com
# 1               Twitter for iPhone
# 2                        Periscope
# ...

# %%
from pandas import DataFrame
df_test = pd.concat([tweets_Conor_Khabib,text_ufc229_df])
df_test_d = df_test.drop_duplicates(keep = 'first')
df_test_d
# Out:
#                    User              Date Created  Number of Likes  \
# 0       TheNotoriousMMA 2018-10-06 07:44:43+00:00            36862
# 1       TheNotoriousMMA 2018-10-06 02:15:36+00:00            10588
# 2       TheNotoriousMMA 2018-10-06 01:54:47+00:00           161711
# 3            TeamKhabib 2018-10-05 08:20:13+00:00             3623
# 4            TeamKhabib 2018-10-04 21:29:07+00:00             3071
# ...                 ...                       ...              ...
# 338873    ShoMEyourNUTS 2018-08-23 00:01:28+00:00                0
# 338874    mmasocialclub 2018-08-23 00:01:10+00:00                0
# 338875       angrymarks 2018-08-23 00:01:02+00:00                0
# 338876   DJANONYMOUSDRG 2018-08-23 00:00:54+00:00                0
# 338877         mmamania 2018-08-23 00:00:05+00:00                2
#
#                    Source of Tweet  \
# 0               Twitter for iPhone
# 1                        Instagram
# 2               Twitter for iPhone
# ...

# %%
df_test_d.to_csv('MMA_tweets_data.csv', index = False)
